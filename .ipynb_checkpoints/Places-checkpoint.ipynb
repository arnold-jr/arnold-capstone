# %% [markdown]
# # AmeniDC
# ## See the cost of amenities in the District of Columbia

# %%
# %load_ext autoreload
# %autoreload 2

# %%
# %matplotlib inline
import matplotlib
import seaborn as sns
matplotlib.rcParams['savefig.dpi'] = 4 * matplotlib.rcParams['savefig.dpi']
import matplotlib.pylab as plt
from globals import AMENITY_TYPES

# %% [markdown]
# # Overview
#
# 1. generate grid points
# 1. query grid points for all amenity types and store in database
# 1. load amenities from other sources:
#     1. load crime locations
#     1. load tree locations
#     1. load bikeshare locations
# 1. load property sale locations
# 1. derive features from amenities (or anti-amenities)
#     1. query features at distinct radii
#     1. perform dimensionality reduction with random projections
#     1.

# %% [markdown]
# # Generate grid points
# Space points on a grid of equilateral triangles

# %% [markdown]
# Prove that the covering radius should be $ \frac{h}{\sqrt{3}}$

# %%
# %autoreload 2
from demo_equilateral_grid import plot_radii

plot_radii()

# %%
# %autoreload 2
from grid_points import generate_grid_points

RADIUS = 500

lat, lng, lat_lng_strs = generate_grid_points(radius=RADIUS)

fig,ax = plt.subplots(1,1)
ax.scatter(lng,lat,s=5)
print('{0} total queries required'.format(len(AMENITY_TYPES)*len(lat)))

lat, lng = np.array(lat), np.array(lng)
# Out:
# 52598 total queries required

# %%
bnd_box=(-77.15,-76.88,38.78,39.01)
x0, x1, y0, y1 = bnd_box

N = 500

lng = np.random.rand(N)*(x1-x0)+x0
lat = np.random.rand(N)*(y1-y0)+y0
in_diamond = np.abs((lat - 0.5*(y0+y1))/(y1-y0)) + np.abs((lng - 0.5*(x0+x1))/(x1-x0)) < 0.6

lng, lat = lng[in_diamond], lat[in_diamond]

fig,ax = plt.subplots(1,1)
ax.scatter(lng,lat,s=5)

# %%
from sklearn.neighbors import DistanceMetric
dist = DistanceMetric.get_metric('haversine')
X = df[['lat','lng']].sample(100)
dist.pairwise(X).shape
# Out:
# (100, 100)

# %%
def coord_to_meters(lng, lat):
  return np.column_stack((111111 * lng * np.cos(np.deg2rad(lat[len(lat) // 2])),
    111111 * lat))

# %%
xy = coord_to_meters(lng,lat)

# %%
coord_to_meters(np.array([0]), np.array([1]))
# Out:
# array([[      0.,  111111.]])

# %%
coord_to_meters(X[:,0], X[:,1])
# Out:
# array([[-6664139.32937411,  4320681.0570924 ],
#        [-6654211.22221864,  4324853.897364  ],
#        [-6661555.71944362,  4328681.3824254 ],
#        [-6652645.04704591,  4319125.014204  ],
#        [-6664018.40025246,  4324714.341948  ],
#        [-6651038.07525721,  4317940.793166  ],
#        [-6656361.3421743 ,  4314031.352631  ],
#        [-6658180.42179269,  4324867.675128  ],
#        [-6663239.72077503,  4315285.68471   ],
#        [-6662629.50020553,  4323463.3209768 ],
#        [-6658898.3903738 ,  4322592.5551809 ],
#        [-6656341.28960034,  4330274.669721  ],
#        [-6658110.15135033,  4324410.342252  ],
#        [-6662904.40197909,  4321165.123275  ],
#        [-6661741.95772423,  4327522.561362  ],
#        [-6654813.05873782,  4314474.018855  ],
#        [-6656806.68218313,  4309068.913149  ],
#        [-6650351.53389976,  4327837.116603  ],
#        [-6660944.72961589,  4323320.0322312 ],
#        [-6660446.01691561,  4311796.688199  ],
#        [-6648228.72693276,  4326945.561939  ],
#        [-6666459.02322996,  4321001.8678827 ],
#        [-6660950.09713676,  4323224.5545489 ],
#        [-6664400.09062568,  4320124.902093  ],
#        [-6661687.2798868 ,  4326088.3627962 ],
#        [-6657342.708229  ,  4325102.1860046 ],
#        [-6663831.19391656,  4327336.8393255 ],
#        [-6659367.97498174,  4322646.6106824 ],
#        [-6655553.64696809,  4328089.8052392 ],
#        [-6652547.9735726 ,  4319073.4587    ],
#        [-6659714.37455347,  4317112.8828828 ],
#        [-6654092.8947456 ,  4333374.333288  ],
#        [-6659336.8243453 ,  4323666.4985514 ]])

# %%
cdist(coord_to_meters(X[:,0], X[:,1]), np.array([[x[0], y[0]]]), 'cityblock')
# Out:
# array([[ 17574.44150288],
#        [ 17315.14392347],
#        [  6990.50623939],
#        [ 24610.20225619],
#        [ 13420.22752563],
#        [ 27401.39508289],
#        [ 25987.5687008 ],
#        [ 13332.16658542],
#        [ 22070.2052862 ],
#        [ 13282.3484499 ],
#        [ 14889.31795141],
#        [  9764.30418476],
#        [ 13859.76990377],
#        [ 15855.44792525],
#        [  8335.5655834 ],
#        [ 27093.18591328],
#        [ 30504.66817397],
#        [ 18191.61300334],
#        [ 12115.50165901],
#        [ 24137.55839149],
#        [ 21205.97463434],
#        [ 19573.32456843],
#        [ 12205.61182044],
#        [ 18391.35775385],
#        [  9715.08631177],
#        [ 18326.5518045 ],
#        [ 14186.54156862],
#        [ 11345.08366656],
#        [ 22097.58632128],
#        [ 14681.01946958],
#        [ 15956.36061455],
#        [ 14411.00184693],
#        [ 10883.26153646],
#        [  6833.10836034],
#        [  7625.74387404],
#        [ 25160.26292538],
#        [ 13405.97503145],
#        [ 20053.27280434],
#        [ 17352.5604397 ],
#        [  5849.71997092],
#        [ 13049.46177746],
#        [ 12865.50431191],
#        [ 13938.9959209 ],
#        [ 23565.65374092],
#        [ 11240.25661677],
#        [ 19041.99203451],
#        [ 31920.29323631],
#        [ 24532.09029041],
#        [ 27001.52174383],
#        [ 31331.73180226],
#        [ 12921.50282397],
#        [ 23195.02769706],
#        [ 31418.52498448],
#        [ 23230.81798938],
#        [ 19080.11067352],
#        [ 18403.10230369],
#        [ 21351.49245341],
#        [ 15592.87872217],
#        [ 21234.82509014],
#        [ 14327.11589019],
#        [ 24349.29959175],
#        [ 22849.16926711],
#        [ 23005.79169599],
#        [ 16277.80269541],
#        [ 13758.69181759],
#        [ 18482.56343898],
#        [ 14498.99943563],
#        [ 21830.894617  ],
#        [ 18681.87002999],
#        [ 19046.45724061],
#        [ 15348.47767613],
#        [ 22471.98096666],
#        [  7654.43744422],
#        [ 17746.63001692],
#        [ 17496.68313888],
#        [ 16812.24598697],
#        [ 17314.57247924],
#        [ 14856.2710825 ],
#        [ 14402.01526168],
#        [ 17786.63185203],
#        [ 16748.30551227],
#        [ 18763.44085446],
#        [ 17889.8280314 ],
#        [ 15585.94587684],
#        [ 11072.24402202],
#        [ 23119.21146654],
#        [ 19277.41663427],
#        [ 19972.18841385],
#        [ 25480.5827985 ],
#        [  8743.35699605],
#        [  7865.84765654],
#        [ 16897.79385431],
#        [ 13935.3692725 ],
#        [ 10610.52381223],
#        [ 14365.67784197],
#        [ 12736.81129881],
#        [ 24758.83123351],
#        [ 19553.00606984],
#        [  8913.0354725 ],
#        [ 13376.9406094 ]])

# %%
cdist?

# %%
from scipy.spatial.distance import cdist, pdist

X = df[['lng','lat']].sample(100).as_matrix()
cdist(X, np.array([lng[0], lat[0]]))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-275-ede9de56a39f> in <module>()
#       2
#       3 X = df[['lng','lat']].sample(100).as_matrix()
# ----> 4 cdist(X, np.array([lng[0], lat[0]]))
#
# /Users/joshuaarnold/anaconda/lib/python3.5/site-packages/scipy/spatial/distance.py in cdist(XA, XB, metric, p, V, VI, w)
#    2027         raise ValueError('XA must be a 2-dimensional array.')
#    2028     if len(sB) != 2:
# -> 2029         raise ValueError('XB must be a 2-dimensional array.')
#    2030     if s[1] != sB[1]:
#    2031         raise ValueError('XA and XB must have the same number of columns '
#
# ValueError: XB must be a 2-dimensional array.

# %%
# %autoreload 2
from convex_regions import create_convex_regions
from kernel_density import calc_kernel_density


# create_convex_regions(df_sale)
polygons = create_convex_regions(df_sale,n_clusters=1)

calc_kernel_density(df_sale.loc[:,['lng','lat']],polygons)

# %%
import pandas as pd
df = pd.read_hdf('DATA/amenity_db.h5')

for col in df.columns:
  print(col)
# Out:
# Unnamed: 0
# accounting
# airport
# amusement_park
# aquarium
# art_gallery
# atm
# bakery
# bank
# bar
# beauty_salon
# bicycle_store
# book_store
# bowling_alley
# bus_station
# cafe
# campground
# car_dealer
# car_rental
# car_repair
# car_wash
# casino
# cemetery
# church
# city_hall
# clothing_store
# convenience_store
# courthouse
# dentist
# department_store
# doctor
# electrician
# electronics_store
# embassy
# fire_station
# florist
# food (deprecated)
# funeral_home
# furniture_store
# gas_station
# grocery_or_supermarket
# gym
# hair_care
# hardware_store
# hindu_temple
# home_goods_store
# hospital
# id
# insurance_agency
# jewelry_store
# lat
# laundry
# lawyer
# library
# liquor_store
# lng
# local_government_office
# locksmith
# lodging
# meal_delivery
# meal_takeaway
# mosque
# movie_rental
# movie_theater
# moving_company
# museum
# name
# night_club
# num_photos
# painter
# park
# parking
# pet_store
# pharmacy
# physiotherapist
# place_id
# plumber
# police
# post_office
# price_level
# rating
# real_estate_agency
# restaurant
# roofing_contractor
# rv_park
# school
# shoe_store
# shopping_mall
# spa
# stadium
# storage
# store
# subway_station
# synagogue
# taxi_stand
# train_station
# transit_station
# travel_agency
# university
# veterinary_care
# vicinity
# zoo

# %%
trains = df.loc[df.train_station==1,["lat","lng","rating"]]

# %%
trains
# Out:
#             lat        lng  rating
# 259   38.993660 -77.030082     NaN
# 54    38.898119 -77.006358     NaN
# 55    38.898516 -77.006683     NaN
# 1     38.993660 -77.030082     NaN
# 44    38.885598 -77.006066     NaN
# 0     38.997452 -77.033095     NaN
# 1     38.992936 -77.030270     4.1
# 2     38.993660 -77.030082     NaN
# 3     38.963005 -76.934963     NaN
# 4     38.916557 -76.916887     NaN
# 5     38.896769 -77.017536     NaN
# 6     38.896769 -77.017536     NaN
# 7     38.897883 -77.005842     4.0
# 8     38.898119 -77.006358     NaN
# 9     38.898516 -77.006683     NaN
# 10    38.885598 -77.006066     NaN
# 11    38.845020 -76.930664     NaN
# 12    38.806451 -77.062248     4.3
# 13    38.807344 -77.059719     4.0
# 127   38.997452 -77.033095     NaN
# 257   38.992936 -77.030270     4.1
# 262   38.993660 -77.030082     NaN
# 966   38.963005 -76.934963     NaN
# 2110  38.916557 -76.916887     NaN
# 2927  38.896769 -77.017536     NaN
# 2946  38.896769 -77.017536     NaN
# 2967  38.897883 -77.005842     4.0
# 2968  38.898119 -77.006358     NaN
# 2969  38.898516 -77.006683     NaN
# 3292  38.885598 -77.006066     NaN
# 4632  38.845020 -76.930664     NaN
# 5306  38.806451 -77.062248     4.3
# 5307  38.807344 -77.059719     4.0

# %%
import requests

url = "http://opendata.dc.gov/datasets/2acc75ccdd954267acecb8713b2b800a_28.geojson"
#url = 'http://opendata.dc.gov/datasets/2acc75ccdd954267acecb8713b2b800a_28.geojson?where=&geometry={"xmin":-8578773.870344311,"ymin":4713442.284345528,"xmax":-8573189.189965077,"ymax":4714875.478625912,"spatialReference":{"wkid":102100,"latestWkid":3857}}'
with open("DATA/resp.json", "w") as f:
  with requests.Session() as s:
    resp = s.get(url, stream=True)
    for line in resp.json()['features']:
      f.write(json.dumps(line) + "\n")

# %%
with open("DATA/resp.json", "r") as f:
  resp_jsons = (json.loads(line) for line in f.readlines()) 

df_raw = pd.DataFrame.from_records(resp_jsons)

# %%
df_raw.sample(5)
# Out:
#                                                 geometry  \
# 9586   {'coordinates': [-76.9952291041, 38.890764494]...
# 15018  {'coordinates': [-77.0969366733, 38.9171092368...
# 4397   {'coordinates': [-77.048880734, 38.9146131177]...
# 15674  {'coordinates': [-77.0104012933, 38.9569072916...
# 7707   {'coordinates': [-77.0731032796, 38.9128873431...
#
#                                               properties     type
# 9586   {'NBHD': '009', 'PY1COLL': 3708.56, 'CY2INT': ...  Feature
# 15018  {'NBHD': '041', 'PY1COLL': 1975.22, 'CY2INT': ...  Feature
# 4397   {'NBHD': '029', 'PY1COLL': 20523.28, 'CY2INT':...  Feature
# 15674  {'NBHD': '012', 'PY1COLL': 1287.94, 'CY2INT': ...  Feature
# 7707   {'NBHD': '008', 'PY1COLL': 5670.6, 'CY2INT': 0...  Feature

# %%
df_sale = pd.concat([
    df_raw.geometry.apply(
      lambda d: pd.Series({"lng":d['coordinates'][0], "lat": d['coordinates'][1]})),
    df_raw.properties.apply(lambda d: pd.Series(d)) 
          ], axis=1)

# %%
df_sale.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18568 entries, 0 to 18567
# Columns: 211 entries, lat to Y_COORD
# dtypes: float64(105), int64(31), object(75)
# memory usage: 29.9+ MB

# %%
from sklearn.base import BaseEstimator, TransformerMixin
import numpy as np

class MeanEstimator(BaseEstimator, TransformerMixin):
  def __init__(self):
    self.mean = None
    pass
  
  def fit(self, X, y):
    self.mean = y.mean()
    return self
  
  def predict(self, X):
    return self.mean * np.ones(X.shape[0]).reshape(-1,1)
  
  def score(self, X, y):
    return y.var()

# %%
clf_mean = MeanEstimator().fit(X,y)
clf_mean.predict(X)
# Out:
# array([[ 1473532.67842525],
#        [ 1473532.67842525],
#        [ 1473532.67842525],
#        ...,
#        [ 1473532.67842525],
#        [ 1473532.67842525],
#        [ 1473532.67842525]])

# %% [markdown]
# ### Compare to training error to test error

# %%
numeric_cols = df_sale.dtypes.apply(lambda t: t == np.float64 or t == np.int64)
df_sale.loc[:,np.logical_not(numeric_cols)]
# Out:
#       ABTLOTCODE              ACCEPTCODE                      ADDRESS1  \
# 0                 M1 MULTI-VERIFIED SALE            506 EASTERN AVE NE
# 1                  001   ...         3198            EASTERN AV       C
# 2                  001   ...         2158            CENTRAL AV       C
# 3                  001   ...         0540               54TH ST       C
# 4                  001   ...         0533               53RD PL       C
# 5                  001   ...         0533               53RD PL       C
# 6                  001   ...         0540               54TH ST       C
# 7                  001   ...         0550               55TH ST       C
# 8                  001   ...         0420               42ND ST       A
# 9                  001   ...         0423               42ND PL       A
# 10                 001   ...         1033          ANACOSTIA AV       A
# 11                 001   ...         0453               45TH PL       A
# 12                 001   ...         0440               44TH ST       A
# 13                 001   ...         0440               44TH ST       A
# 14                 001   ...         7098               POLK ST       A
# 15                 001   ...         3022            DOUGLAS ST       A
# 16                 003   ...         3022            DOUGLAS ST       A
# 17                 001   ...         3022            DOUGLAS ST       A
# 18                 001   ...         6708              OLIVE ST       A
# 19         Y       001   ...         6708              OLIVE ST       A
# 20                 001   ...         0453               45TH PL       B
# 21                 001   ...         7995            SHERIFF RD       B
# 22         Y       001   ...         0453               45TH PL       B
# 23         Y       001   ...         0460               46TH ST       B
# 24                       ...         7995            SHERIFF RD       B
# 25                 001   ...         4719               HUNT PL       B
# 26                 001   ...         4719               HUNT PL       B
# 27         Y       001   ...         4972                JAY ST       B
# 28                 001   ...         4972                JAY ST       B
# 29                 003   ...         0460               46TH ST       B
# ...      ...       ...   ...          ...                   ...     ...
# 18538              001   ...         7670  ROCK CREEK CHURCH RD       D
# 18539              001   ...         6142             MONROE ST       D
# 18540              001   ...         6142             MONROE ST       D
# 18541              001   ...         6142             MONROE ST       D
# 18542              001   ...         6142             MONROE ST       D
# 18543              001   ...         6142             MONROE ST       D
# 18544              001   ...         6142             MONROE ST       D
# 18545              001   ...         6142             MONROE ST       D
# 18546              001   ...         6142             MONROE ST       D
# 18547              001   ...         6142             MONROE ST       D
# 18548              001   ...         6142             MONROE ST       D
# 18549              001   ...         6142             MONROE ST       D
# 18550              001   ...         6142             MONROE ST       D
# 18551              001   ...         6142             MONROE ST       D
# 18552              001   ...         6142             MONROE ST       D
# 18553              001   ...         6142             MONROE ST       D
# 18554              001   ...         6142             MONROE ST       D
# 18555              001   ...         6142             MONROE ST       D
# 18556              001   ...         6142             MONROE ST       D
# 18557              001   ...         6142             MONROE ST       D
# 18558              001   ...         6142             MONROE ST       D
# 18559              001   ...         6142             MONROE ST       D
# 18560              001   ...         6142             MONROE ST       D
# 18561              001   ...         6142             MONROE ST       D
# 18562              001   ...         6142             MONROE ST       D
# 18563              001   ...         6142             MONROE ST       D
# 18564              001   ...         4043             GIRARD ST       E
# 18565              001   ...         4043             GIRARD ST       E
# 18566              001   ...         4043             GIRARD ST       E
# 18567              001   ...         4043             GIRARD ST       E
#
#       SUFFIX TRIGROUP TXSALEDESC UNITNUMBER USECODE VACLNDUSE X_COORD
# 0                   3                           023         N    None
# 1                   3                           094         Y    None
# 2                   3                           012         N    None
# 3                   3                           013         N    None
# 4                   3                           012         N    None
# 5                   3                           012         N    None
# 6                   3                           013         N    None
# 7                   3                           013         N    None
# 8                   3                           012         N    None
# 9                   3                           012         N    None
# 10                  3                           013         N    None
# 11                  3                           023         N    None
# 12                  3                           012         N    None
# 13                  3                           012         N    None
# 14                  3                           091         Y    None
# 15                  3                           012         N    None
# 16                  3                           012         N    None
# 17                  3                           012         N    None
# 18                  3                           023         N    None
# 19                  3                           012         N    None
# 20                  3                           012         N    None
# 21                  3                           012         N    None
# 22                  3                           012         N    None
# 23                  3                           013         N    None
# 24                  3                           191         Y    None
# 25                  3                           024         N    None
# 26                  3                           021         N    None
# 27                  3                           012         N    None
# 28                  3                           012         N    None
# 29                  3                           012         N    None
# ...      ...      ...        ...        ...     ...       ...     ...
# 18538               1                   305     016         N    None
# 18539               1                   101     016         N    None
# 18540               1                   201     016         N    None
# 18541               1                   202     016         N    None
# 18542               1                   203     016         N    None
# 18543               1                   204     016         N    None
# 18544               1                   205     016         N    None
# 18545               1                   206     016         N    None
# 18546               1                   207     016         N    None
# 18547               1                   208     016         N    None
# 18548               1                   209     016         N    None
# 18549               1                   301     016         N    None
# 18550               1                   302     016         N    None
# 18551               1                   303     016         N    None
# 18552               1                   304     016         N    None
# 18553               1                   305     016         N    None
# 18554               1                   306     016         N    None
# 18555               1                   307     016         N    None
# 18556               1                   309     016         N    None
# 18557               1                   401     016         N    None
# 18558               1                   403     016         N    None
# 18559               1                   404     016         N    None
# 18560               1                   405     016         N    None
# 18561               1                   406     016         N    None
# 18562               1                   407     016         N    None
# 18563               1                   408     016         N    None
# 18564               1                     1     016         N    None
# 18565               1                     2     016         N    None
# 18566               1                     3     016         N    None
# 18567               1                     4     016         N    None
#
# [18568 rows x 75 columns]

# %%
for col in df_sale.columns[\numeric_cols]:
  print(col)
# Out:
# lat
# lng
# AMTDUE1
# AMTDUE2
# AMTDUE3
# ANNUALTAX
# ASSESSMENT
# BASEBUILD
# BASELAND
# CAPCURR
# CAPPROP
# CLASS3EX
# COOPUNITS
# CY1BAL
# CY1COLL
# CY1CR
# CY1FEE
# CY1INT
# CY1PEN
# CY1TAX
# CY1TOTDUE
# CY2BAL
# CY2COLL
# CY2CR
# CY2FEE
# CY2INT
# CY2PEN
# CY2TAX
# CY2TOTDUE
# LANDAREA
# MIX1BLDPCT
# MIX1BLDVAL
# MIX1LNDPCT
# MIX1LNDVAL
# MIX1RATE
# MIX2BLDPCT
# MIX2BLDVAL
# MIX2LNDPCT
# MIX2LNDVAL
# MIX2RATE
# NEWIMPR
# NEWLAND
# NEWTOTAL
# OBJECTID
# OLDIMPR
# OLDLAND
# OLDTOTAL
# OWNOCCT
# PHASEBUILD
# PHASELAND
# PY10BAL
# PY10COLL
# PY10CR
# PY10FEE
# PY10INT
# PY10PEN
# PY10TAX
# PY10TOTDUE
# PY1BAL
# PY1COLL
# PY1CR
# PY1FEE
# PY1INT
# PY1PEN
# PY1TAX
# PY1TOTDUE
# PY2BAL
# PY2COLL
# PY2CR
# PY2FEE
# PY2INT
# PY2PEN
# PY2TAX
# PY2TOTDUE
# PY3BAL
# PY3COLL
# PY3CR
# PY3FEE
# PY3INT
# PY3PEN
# PY3TAX
# PY3TOTDUE
# PY4BAL
# PY4COLL
# PY4CR
# PY4FEE
# PY4INT
# PY4PEN
# PY4TAX
# PY4TOTDUE
# PY5BAL
# PY5COLL
# PY5CR
# PY5FEE
# PY5INT
# PY5PEN
# PY5TAX
# PY5TOTDUE
# PY6BAL
# PY6COLL
# PY6CR
# PY6FEE
# PY6INT
# PY6PEN
# PY6TAX
# PY6TOTDUE
# PY7BAL
# PY7COLL
# PY7CR
# PY7FEE
# PY7INT
# PY7PEN
# PY7TAX
# PY7TOTDUE
# PY8BAL
# PY8COLL
# PY8CR
# PY8FEE
# PY8INT
# PY8PEN
# PY8TAX
# PY8TOTDUE
# PY9BAL
# PY9COLL
# PY9CR
# PY9FEE
# PY9INT
# PY9PEN
# PY9TAX
# PY9TOTDUE
# SALEPRICE
# TAXRATE
# TOTBALAMT
# TOTCOLAMT
# TOTDUEAMT
# Y_COORD

# %%
from sklearn.neighbors import KNeighborsRegressor, RadiusNeighborsRegressor
from sklearn.ensemble import RandomForestRegressor, AdaBoostRegressor
from sklearn.dummy import DummyRegressor
from sklearn.cross_validation import ShuffleSplit
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split
from sklearn.feature_selection import SelectKBest, f_regression
from sklearn.pipeline import Pipeline

X = df_sale.loc[:,["lat","lng"]]
y = df_sale.SALEPRICE

ss = ShuffleSplit(len(y), n_iter=5, test_size=0.3, random_state=42)
def compute_error(model): 
  
  J_train, J_test = 0, 0
  for train_index, test_index in ss:
    X_train, X_test = X.iloc[train_index, :], X.iloc[test_index, :]
    y_train, y_test = y.iloc[train_index], y.iloc[test_index]
    
    model.fit(X_train, y_train)
    
    J_train += mean_squared_error(model.predict(X_train), y_train)
    J_test += mean_squared_error(model.predict(X_test), y_test)
    

  return (J_train, J_test)

pipe = Pipeline([
    ("best_features", SelectKBest(f_regression, k=2)),
    ("Random Forest", RandomForestRegressor()),
  ])

models = [
    ("Random Forest", RandomForestRegressor()),
    ("Pruned random forest", pipe),
  ]

model_performance = pd.DataFrame(
  [(name, *compute_error(model)) for name, model in models],
 columns=["Model", "MSE_train", "MSE_test"])

model_performance = model_performance.set_index("Model")

model_performance.plot.bar()
print(model_performance.head())
# Out:
#                          MSE_train      MSE_test
# Model
# Random Forest         1.012901e+14  2.673124e+14
# Pruned random forest  9.523622e+13  2.961610e+14

# %% [markdown]
# ### Compare to mean and median models

# %%
from sklearn.neighbors import KNeighborsRegressor, RadiusNeighborsRegressor
from sklearn.ensemble import RandomForestRegressor, AdaBoostRegressor
from sklearn.dummy import DummyRegressor
from sklearn.cross_validation import ShuffleSplit
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split

X = df_sale[['lng','lat']]
y = df_sale.SALEPRICE
X_train, X_test, y_train, y_test = \
  train_test_split(X, y, test_size=0.3, random_state=42)

def compute_error(model): 
    model.fit(X_train, y_train)
    J_train = mean_squared_error(model.predict(X_train), y_train)
    J_test = mean_squared_error(model.predict(X_test), y_test)
    return (J_train, J_test)

  
models = [
    ("Mean Model", DummyRegressor(strategy="mean")),
    ("Median Model", DummyRegressor(strategy="median")),
    ("Random Forest", RandomForestRegressor()),
  ]

model_performance = pd.DataFrame(
  [(name, compute_error(model)[1]) for name, model in models],
 columns=["Model", "MSE_test"])

model_performance = model_performance.set_index("Model")

model_performance.plot.bar()
print(model_performance.head())
# Out:
#                    MSE_test
# Model
# Mean Model     4.679295e+13
# Median Model   4.721741e+13
# Random Forest  2.677860e+13

# %%
from sklearn.neighbors import DistanceMetric
dist = DistanceMetric.get_metric('haversine')
X = df[['lat','lng']].sample(100)
dist.pairwise(X)

# %%
from sklearn.svm import NuSVR
from sklearn import cross_validation, grid_search

X = df[count_cols]
X = (X-X.mean())/X.std()cc
X = X.sample(1000)
y = df.loc[X.index,'SALEPRICE']
if 0:
  clf = NuSVR(C=1.0, nu=0.1)
  clf.fit(X,y)  
  (np.abs(clf.predict(X)-y)).mean()

param_grid = {"nu": np.linspace(0.05,0.7,4),"C": np.logspace(-1,1,3)}
clf_CV = grid_search.GridSearchCV( NuSVR(),
                param_grid=param_grid,
                cv=cross_validation.ShuffleSplit(len(y), n_iter=20, 
                    test_size=0.2, random_state=42) )
clf_CV.fit(X,y)

# %%
for key in param_grid.keys():
  grid_score_plotter(clf_CV,key,title='CV NuSVR')

print clf_CV.best_params_

# %%
from sklearn import cross_validation, grid_search, neighbors
from sklearn.pipeline import Pipeline, FeatureUnion
from sklearn import preprocessing
from sklearn.base import BaseEstimator, TransformerMixin
from sklearn import cross_validation, grid_search, neighbors, ensemble
from sklearn.pipeline import Pipeline
from sklearn import linear_model

# %%
def grid_score_plotter(cv,param,title=None,xlabel=None):
  cv_accuracy = pd.DataFrame.from_records(
      [(score.parameters[param],
        score.mean_validation_score)
       for score in cv.grid_scores_],
  columns=[param, 'accuracy'])

  f = plt.figure(figsize=(4,3))
  plt.plot(cv_accuracy[param], cv_accuracy.accuracy)
  if xlabel is not None:
    plt.xlabel(xlabel)
  else:
    plt.xlabel(param)
  plt.ylabel('accuracy')
  plt.title(title)
  plt.show()
  if title is not None:
    plt.savefig('./static/images/'+title.replace(' ','_')+'.png',frameon=False,dpi=450,pad_inches=0.1)

# %%
class ColumnSelectTransformer(BaseEstimator, TransformerMixin):
  """
  Select columns of data from nd array
  """
  def __init__(self, columns, rescale=None):
    ''' columns must be list of strings '''
    self.columns = columns
    if rescale == "standard" or rescale=="range" or rescale==None:
      self.rescale = rescale
    else:
      raise NameError("rescale option must specify 'standard' or 'range'")

  def fit(self, X, y):
    return self

  def transform(self, X):
    ''' Assume X is pandas dataframe '''
    df = X[self.columns]
    if self.rescale == "standard":
      return (df-df.mean())/df.std()
    elif self.rescale == "range":
      return (df-df.min())/(df.max()-df.min())
    else:
      return df

# %% [markdown]
# ## Build a predictive model using only latitude and longitude using K-nearest neighbors ##

# %%
lat_lng_pipe = Pipeline([
    ('sel',ColumnSelectTransformer(['latitude','longitude'],rescale=None)),
    ('knn',neighbors.KNeighborsRegressor())
  ])

param_grid = {"knn__n_neighbors": range(1,6)}
lat_lng_model_CV = grid_search.GridSearchCV( lat_lng_pipe,
                param_grid=param_grid,
                cv=cross_validation.ShuffleSplit(len(df.index), n_iter=20, 
                    test_size=0.2, random_state=42) )

lat_lng_model_CV.fit(df,df.SALEPRICE)

# %%
for key in param_grid.keys():
  grid_score_plotter(lat_lng_model_CV,key,title='Cross Validation Using Lat-Long',
                        xlabel='Number of Neighbors')

print lat_lng_model_CV.best_params_

# %%
lat_lng_model = lat_lng_pipe.set_params(knn__n_neighbors=2)
lat_lng_model.fit(df,df.SALEPRICE)
computed_error = pd.DataFrame(
  {'lat_lng_err': abs(df.SALEPRICE - lat_lng_model.predict(df))
  })
print computed_error.mean()
lat_lng_model.get_params()

# %%
if 1:
  with open('./data/p_combo_model_rf.dpkl','wb') as p_output:
    pickle.dump(lat_lng_model,p_output)

# %%
stats_pipe = Pipeline([
    ('sel',ColumnSelectTransformer(new_stats_cols,rescale=None)),
    ('knn',neighbors.KNeighborsRegressor())
  ])

param_grid = {"knn__n_neighbors": range(1,6)}
stats_model_CV = grid_search.GridSearchCV( stats_pipe,
                param_grid=param_grid,
                cv=cross_validation.ShuffleSplit(len(df.index), n_iter=20, 
                    test_size=0.2, random_state=42) )

stats_model_CV.fit(df,df.SALEPRICE)

# %%
for key in param_grid.keys():
  f = grid_score_plotter(stats_model_CV,key,title='Cross Validation Using Amenities',
                        xlabel='Number of Neighbors')

print stats_model_CV.best_params_

# %%
stats_pipe = Pipeline([
    ('sel',ColumnSelectTransformer(new_stats_cols,rescale=None)),
    ('model',ensemble.RandomForestRegressor(min_samples_leaf=3))
  ])

param_grid = {"model__min_samples_split": range(2,8,2)}
stats_model_CV = grid_search.GridSearchCV( stats_pipe,
                param_grid=param_grid,
                cv=cross_validation.ShuffleSplit(len(df.index), n_iter=20, 
                    test_size=0.2, random_state=42) )

stats_model_CV.fit(df,df.SALEPRICE)

for key in param_grid.keys():
  grid_score_plotter(stats_model_CV,key)

# %%
## Combo RF
from sklearn import cross_validation, grid_search, neighbors, ensemble
from sklearn.pipeline import Pipeline
from sklearn.decomposition import PCA
from sklearn import linear_model

combo_pipe = Pipeline([
    ('union',
       FeatureUnion([
              ('lat_lng_pipe',
                 Pipeline([
                  ('sel',ColumnSelectTransformer(['latitude','longitude'],rescale=None)),
                ])
              ),
              ('stats_pipe',
                 Pipeline([
                  ('sel',ColumnSelectTransformer(new_stats_cols,rescale=None)),
                ])
              ),          
      ]) 
    ),  
    ('model',ensemble.RandomForestRegressor())
  ])

param_grid = {"model__min_samples_split": range(1,3),"model__min_samples_leaf": range(1,3)}
combo_model_CV = grid_search.GridSearchCV( combo_pipe,
                param_grid=param_grid,
                cv=cross_validation.ShuffleSplit(len(df.index), n_iter=20, 
                    test_size=0.2, random_state=42) )

combo_model_CV.fit(df,df.SALEPRICE)

for key in param_grid.keys():
  grid_score_plotter(combo_model_CV,key)

computed_error['combo_error'] = abs(df.SALEPRICE - lat_lng_model.predict(df))

print computed_error.mean()
print combo_model_CV.best_params_


#combo_model = combo_pipe.fit(df,df.SALEPRICE)

# %%
print np.mean(np.abs(combo_model.predict(df) - df.SALEPRICE))
if 1:
  with open('./data/p_combo_model_rf.dpkl','wb') as p_output:
    pickle.dump(combo_model,p_output)

# %%
neighbors.KNeighborsRegressor?

# %%
## Combo KNN
from sklearn import cross_validation, grid_search, neighbors, ensemble
from sklearn.pipeline import Pipeline
from sklearn.decomposition import PCA
from sklearn import linear_model

combo_pipe = Pipeline([
    ('union',
       FeatureUnion([
              ('landarea_pipe',
                 Pipeline([
                  ('sel',ColumnSelectTransformer(['LANDAREA'])),
                  ('scaling', preprocessing.StandardScaler(copy=True)),
                ])
              ),
              ('lat_lng_pipe',
                 Pipeline([
                  ('sel',ColumnSelectTransformer(['latitude','longitude'])),
                  ('scaling', preprocessing.MinMaxScaler(copy=True)),
                ])
              ),
              ('stats_pipe',
                 Pipeline([
                  ('sel',ColumnSelectTransformer(new_stats_cols)),
                  ('scaling', preprocessing.StandardScaler(copy=True)),
                ])
              ),          
      ]) 
    ),  
    ('model',neighbors.KNeighborsRegressor())
  ])

if 1:
  param_grid = {"model__n_neighbors": range(1,9)}
  combo_model = grid_search.GridSearchCV( combo_pipe,
                  param_grid=param_grid,
                  cv=cross_validation.ShuffleSplit(len(df.index), n_iter=20, 
                      test_size=0.2, random_state=42) )

  combo_model.fit(df,df.SALEPRICE)

  for key in param_grid.keys():
    grid_score_plotter(combo_model,key)
else:
  combo_model = combo_pipe.fit(df,df.SALEPRICE)

# %%
np.mean(np.abs(X.SALEPRICE-full_pipe.predict(X)))
